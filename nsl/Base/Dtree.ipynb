# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,f1_score
from yellowbrick.classifier import ConfusionMatrix
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pickle
with open('merge.pkl', 'rb') as f:
  X_treino, X_teste, y_treino, y_teste = pickle.load(f)

# %%
modelo = DecisionTreeClassifier(max_depth=3)
modelo.fit(X_treino,y_treino)
df = pd.read_csv('Trat2.csv')

# %%
sns.countplot(x = df['class'])
df = df.drop('class',axis=1)

# %%
previsoes = modelo.predict(X_teste)
accuracy_score(y_teste,previsoes)
# Out:
# 0.9666177112690033

# %%
confusion_matrix(y_teste, previsoes)
# Out:
# array([[11164,   478],
#        [  363, 13188]], dtype=int64)

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_teste, y_teste)
# Out:
# 0.9666177112690033

# %%
previsores = df.columns
class_names = [str(cls) for cls in modelo.classes_]
print(len(previsores))
figura, eixos = plt.subplots(nrows=1, ncols=1, figsize=(100,100))
tree.plot_tree(modelo, filled=True, feature_names=previsores, class_names=class_names)
tree.plot_tree(modelo, feature_names=previsores, class_names = class_names, filled=True)
# Out:
# 122
# [Text(0.5, 0.875, "flag_b'SF' <= 0.5\ngini = 0.498\nsamples = 100771\nvalue = [46979.0, 53792.0]\nclass = 1"),
#  Text(0.25, 0.625, 'dst_host_same_srv_rate <= 0.575\ngini = 0.144\nsamples = 40881\nvalue = [37698, 3183]\nclass = 0'),
#  Text(0.125, 0.375, 'dst_bytes <= 0.0\ngini = 0.024\nsamples = 37898\nvalue = [37437, 461]\nclass = 0'),
#  Text(0.0625, 0.125, 'gini = 0.013\nsamples = 37684\nvalue = [37435, 249]\nclass = 0'),
#  Text(0.1875, 0.125, 'gini = 0.019\nsamples = 214\nvalue = [2.0, 212.0]\nclass = 1'),
#  Text(0.375, 0.375, 'dst_host_srv_serror_rate <= 0.225\ngini = 0.16\nsamples = 2983\nvalue = [261, 2722]\nclass = 1'),
#  Text(0.3125, 0.125, 'gini = 0.094\nsamples = 2853\nvalue = [141, 2712]\nclass = 1'),
#  Text(0.4375, 0.125, 'gini = 0.142\nsamples = 130\nvalue = [120, 10]\nclass = 0'),
#  Text(0.75, 0.625, "protocol_type_b'icmp' <= 0.5\ngini = 0.262\nsamples = 59890\nvalue = [9281, 50609]\nclass = 1"),
#  Text(0.625, 0.375, "service_b'private' <= 0.5\ngini = 0.129\nsamples = 53265\nvalue = [3705, 49560]\nclass = 1"),
#  Text(0.5625, 0.125, 'gini = 0.069\nsamples = 50594\nvalue = [1821, 48773]\nclass = 1'),
#  Text(0.6875, 0.125, 'gini = 0.416\nsamples = 2671\nvalue = [1884.0, 787.0]\nclass = 0'),
#  Text(0.875, 0.375, 'diff_srv_rate <= 0.02\ngini = 0.267\nsamples = 6625\nvalue = [5576, 1049]\nclass = 0'),
#  Text(0.8125, 0.125, 'gini = 0.143\nsamples = 6032\nvalue = [5566, 466]\nclass = 0'),
#  Text(0.9375, 0.125, 'gini = 0.033\nsamples = 593\nvalue = [10, 583]\nclass = 1')]
